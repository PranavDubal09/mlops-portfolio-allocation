# %%
import os

import pandas as pd 
import numpy as np
import datetime

  # can directly import from the folder by defining the folder name

# %%
os.chdir(r"D:\1.Work\WorkStation\WorkSpace\Projects\Dynamic-Portfolio-Allocation")
path = os.getcwd()

from data.metadata import features, stocks
from src.ingest import update_ticker

# %%
datetime.date.today()
# Out:
# 2026-04-11

# %%
'''
for i in features:
    update_ticker(i,path)

for i in stocks:
    update_ticker(i,path)
'''
# Out:
# '\nfor i in features:\n    update_ticker(i,path)\n\nfor i in stocks:\n    update_ticker(i,path)\n'

# %%
df = pd.DataFrame()

for i in features:
    if df.empty:
        df = pd.read_csv(os.path.join(path,'data','processed',f'p-{i}.csv'),index_col=0)
        df.set_index('Date',inplace=True)
    else:
        right = pd.read_csv(os.path.join(path,'data','processed',f'p-{i}.csv'),index_col=0)
        right.set_index('Date',inplace=True)
    
        df = pd.concat([df,right],join='inner',axis=1)
        
df.to_csv(os.path.join(path,'data','final','Dataset.csv'))

# %%
df
# Out:
#              GSPC-Close  GSPC-Dividends    GSPC-High     GSPC-Low  \
# Date
# 2015-11-18  2083.580078             0.0  2085.310059  2051.989990
# 2015-11-19  2081.239990             0.0  2086.739990  2078.760010
# 2015-11-20  2089.169922             0.0  2097.060059  2082.820068
# 2015-11-24  2089.139893             0.0  2094.120117  2070.290039
# 2015-11-27  2090.110107             0.0  2093.290039  2084.129883
# ...                 ...             ...          ...          ...
# 2025-11-11  6846.609863             0.0  6855.129883  6806.870117
# 2025-11-12  6850.919922             0.0  6869.910156  6829.620117
# 2025-11-13  6737.490234             0.0  6828.049805  6724.720215
# 2025-11-14  6734.109863             0.0  6774.310059  6646.870117
# 2025-11-17  6672.410156             0.0  6754.500000  6638.899902
#
#               GSPC-Open  GSPC-Stock Splits  GSPC-Volume     SS-Close  \
# Date
# 2015-11-18  2051.989990                0.0   3926390000  3568.468018
# ...

# %%
pd.read_csv(os.path.join(path,'data','final','Dataset.csv'))
# Out:
#             Date   GSPC-Close  GSPC-Dividends    GSPC-High     GSPC-Low  \
# 0     2015-11-18  2083.580078             0.0  2085.310059  2051.989990
# 1     2015-11-19  2081.239990             0.0  2086.739990  2078.760010
# 2     2015-11-20  2089.169922             0.0  2097.060059  2082.820068
# 3     2015-11-24  2089.139893             0.0  2094.120117  2070.290039
# 4     2015-11-27  2090.110107             0.0  2093.290039  2084.129883
# ...          ...          ...             ...          ...          ...
# 2069  2025-11-11  6846.609863             0.0  6855.129883  6806.870117
# 2070  2025-11-12  6850.919922             0.0  6869.910156  6829.620117
# 2071  2025-11-13  6737.490234             0.0  6828.049805  6724.720215
# 2072  2025-11-14  6734.109863             0.0  6774.310059  6646.870117
# 2073  2025-11-17  6672.410156             0.0  6754.500000  6638.899902
#
#         GSPC-Open  GSPC-Stock Splits  GSPC-Volume     SS-Close  SS-Dividends  \
# ...

# %%
nvidia = pd.read_csv(os.path.join(path,'data','raw',f'{itemset.stocks[0]}.csv'))

# %%
nvidia.rename(columns={'Price':'Date'},inplace=True)

# %%
nvidia = nvidia.iloc[2:,:]

# %%
nvidia
# Out:
#             Date               Close Dividends                High  \
# 2     2015-12-28  0.8083701133728027       0.0  0.8083701133728027
# 3     2015-12-29  0.8215419054031372       0.0  0.8239811604936232
# 4     2015-12-30  0.8144680857658386       0.0  0.8278840184606137
# 5     2015-12-31  0.8039794564247131       0.0   0.816907517611796
# 6     2016-01-04  0.7895879149436951       0.0  0.7947103350807067
# ...          ...                 ...       ...                 ...
# 2511  2025-12-18  174.13999938964844       0.0  176.14999389648438
# 2512  2025-12-19  180.99000549316406       0.0   181.4499969482422
# 2513  2025-12-22  183.69000244140625       0.0  184.16000366210938
# 2514  2025-12-23   189.2100067138672       0.0   189.3300018310547
# 2515  2025-12-24  188.61000061035156       0.0  188.91000366210938
#
#                      Low                Open Stock Splits     Volume
# 2     0.7893439414695138  0.8005645297370835          0.0  142024000
# ...

# %%
for i in nvidia.columns:
    nvidia = nvidia.iloc[2:,:]
    nvidia.rename(columns={'Price':'Date'},inplace=True)
    # nvidia.set_index('Date')
    nvidia.rename(columns={f'{i}':f'NVDA-{i}'},inplace=True)

# %%
nvidia.iloc[-1]['Date']
# Out:
# '2025-12-24'

# %%
nvidia.rename(columns={'Price','Date'},inplace=True)
# Out:
#       NVDA-Price          NVDA-Close NVDA-Dividends           NVDA-High  \
# 0         Ticker                NVDA           NVDA                NVDA
# 1           Date                 NaN            NaN                 NaN
# 2     2015-12-28  0.8083701133728027            0.0  0.8083701133728027
# 3     2015-12-29  0.8215419054031372            0.0  0.8239811604936232
# 4     2015-12-30  0.8144680857658386            0.0  0.8278840184606137
# ...          ...                 ...            ...                 ...
# 2511  2025-12-18  174.13999938964844            0.0  176.14999389648438
# 2512  2025-12-19  180.99000549316406            0.0   181.4499969482422
# 2513  2025-12-22  183.69000244140625            0.0  184.16000366210938
# 2514  2025-12-23   189.2100067138672            0.0   189.3300018310547
# 2515  2025-12-24  188.61000061035156            0.0  188.91000366210938
#
#                 NVDA-Low           NVDA-Open NVDA-Stock Splits NVDA-Volume
# ...

# %%
nvidia = nvidia.iloc[2:,:]

# %%
nvidia
# Out:
#             Date          NVDA-Close NVDA-Dividends           NVDA-High  \
# 16    2016-01-19  0.6666492819786072            0.0  0.6939689712790597
# 17    2016-01-20  0.6703080534934998            0.0  0.6788454771482242
# 18    2016-01-21  0.6781135201454163            0.0  0.6886023223129522
# 19    2016-01-22   0.693968653678894            0.0  0.6986032552076205
# 20    2016-01-25  0.6932370662689209            0.0  0.7017744894762719
# ...          ...                 ...            ...                 ...
# 2511  2025-12-18  174.13999938964844            0.0  176.14999389648438
# 2512  2025-12-19  180.99000549316406            0.0   181.4499969482422
# 2513  2025-12-22  183.69000244140625            0.0  184.16000366210938
# 2514  2025-12-23   189.2100067138672            0.0   189.3300018310547
# 2515  2025-12-24  188.61000061035156            0.0  188.91000366210938
#
#                 NVDA-Low           NVDA-Open NVDA-Stock Splits NVDA-Volume
# ...
